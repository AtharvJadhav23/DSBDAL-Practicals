# %%
Name :- Atharv Jadhav
Class:- TE(B)
Practical N0.3

# %%
import pandas as pd
df=pd.read_csv("C:/Users/athra/Downloads/Student_performance.csv")
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_joindate  \
# 0           65           86.0             62             80.0           2021
# 1           69          100.0             67             89.0           2020
# 2           76           93.0             71             81.0           2021
# 3           67           88.0             79             83.0           2022
# 4           66           98.0             68             82.0           2020
# 5           67          100.0             80            100.0           2025
# 6           80           91.0             66             84.0           2020
# 7           66           82.0             68            100.0           2021
# 8           72           99.0             64             83.0           2022
# 9           74           80.0             65              NaN           2023
# 10          65           86.0             65             86.0           2024
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_score       44 non-null     int64
#  1   Reading_score    39 non-null     float64
#  2   Writing_score    44 non-null     int64
#  3   Placement_score  40 non-null     float64
#  4   Club_joindate    44 non-null     int64
#  5   Placement_count  44 non-null     int64
# dtypes: float64(2), int64(4)
# memory usage: 2.2 KB

# %%
df.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score  \
# count   44.000000      39.000000      44.000000        40.000000
# mean    70.431818      91.461538      68.909091        87.825000
# std      5.410574       6.064765       6.279602         5.569549
# min     60.000000      80.000000      60.000000        80.000000
# 25%     66.000000      86.500000      63.000000        83.000000
# 50%     70.000000      92.000000      68.000000        88.000000
# 75%     75.250000      97.500000      73.500000        90.250000
# max     80.000000     100.000000      80.000000       100.000000
#
#        Club_joindate  Placement_count
# count      44.000000        44.000000
# mean     2022.431818         2.818182
# std         1.605191         0.869983
# min      2020.000000         2.000000
# 25%      2021.000000         2.000000
# 50%      2023.000000         3.000000
# 75%      2024.000000         4.000000
# max      2025.000000         4.000000

# %%
df.isnull().sum()
# Out:
# Math_score         0
# Reading_score      5
# Writing_score      0
# Placement_score    4
# Club_joindate      0
# Placement_count    0
# dtype: int64

# %%
df.Math_score.max()
# Out:
# 80

# %%
x=df.Math_score.mean()

# %%
df.math_score.fillna(x,inplace=True)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_joindate  \
# 0           65           86.0             62             80.0           2021
# 1           69          100.0             67             89.0           2020
# 2           76           93.0             71             81.0           2021
# 3           67           88.0             79             83.0           2022
# 4           66           98.0             68             82.0           2020
# 5           67          100.0             80            100.0           2025
# 6           80           91.0             66             84.0           2020
# 7           66           82.0             68            100.0           2021
# 8           72           99.0             64             83.0           2022
# 9           74           80.0             65              NaN           2023
# 10          65           86.0             65             86.0           2024
# ...

# %%
y=df.Reading_score.mean()

# %%
df.Reading_score.fillna(y,inplace=True)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_joindate  \
# 0           65           86.0             62             80.0           2021
# 1           69          100.0             67             89.0           2020
# 2           76           93.0             71             81.0           2021
# 3           67           88.0             79             83.0           2022
# 4           66           98.0             68             82.0           2020
# 5           67          100.0             80            100.0           2025
# 6           80           91.0             66             84.0           2020
# 7           66           82.0             68            100.0           2021
# 8           72           99.0             64             83.0           2022
# 9           74           80.0             65              NaN           2023
# 10          65           86.0             65             86.0           2024
# ...

# %%
z=df.Writing_score.mean()

# %%
df.Writing_score.fillna(z,inplace=True)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_joindate  \
# 0           65           86.0             62             80.0           2021
# 1           69          100.0             67             89.0           2020
# 2           76           93.0             71             81.0           2021
# 3           67           88.0             79             83.0           2022
# 4           66           98.0             68             82.0           2020
# 5           67          100.0             80            100.0           2025
# 6           80           91.0             66             84.0           2020
# 7           66           82.0             68            100.0           2021
# 8           72           99.0             64             83.0           2022
# 9           74           80.0             65              NaN           2023
# 10          65           86.0             65             86.0           2024
# ...

# %%
df.iloc[11:12,3:4].fillna(34,inplace=True)

# %%
df.Club_joindate.fillna(2019,inplace=True)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_joindate  \
# 0           65           86.0             62             80.0           2021
# 1           69          100.0             67             89.0           2020
# 2           76           93.0             71             81.0           2021
# 3           67           88.0             79             83.0           2022
# 4           66           98.0             68             82.0           2020
# 5           67          100.0             80            100.0           2025
# 6           80           91.0             66             84.0           2020
# 7           66           82.0             68            100.0           2021
# 8           72           99.0             64             83.0           2022
# 9           74           80.0             65              NaN           2023
# 10          65           86.0             65             86.0           2024
# ...

# %%
df.placement_score.fillna(222,inplace=True)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_joindate  \
# 0           65           86.0             62             80.0           2021
# 1           69          100.0             67             89.0           2020
# 2           76           93.0             71             81.0           2021
# 3           67           88.0             79             83.0           2022
# 4           66           98.0             68             82.0           2020
# 5           67          100.0             80            100.0           2025
# 6           80           91.0             66             84.0           2020
# 7           66           82.0             68            100.0           2021
# 8           72           99.0             64             83.0           2022
# 9           74           80.0             65              NaN           2023
# 10          65           86.0             65             86.0           2024
# ...

# %%
df.placement_count.fillna(10,inplace=True)

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_joindate  \
# 0           65           86.0             62             80.0           2021
# 1           69          100.0             67             89.0           2020
# 2           76           93.0             71             81.0           2021
# 3           67           88.0             79             83.0           2022
# 4           66           98.0             68             82.0           2020
# 5           67          100.0             80            100.0           2025
# 6           80           91.0             66             84.0           2020
# 7           66           82.0             68            100.0           2021
# 8           72           99.0             64             83.0           2022
# 9           74           80.0             65              NaN           2023
# 10          65           86.0             65             86.0           2024
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(9)

# %%
df.columns
# Out:
# Index(['Math_score', 'Reading_score', 'Writing_score', 'Placement_score',
#        'Club_joindate', 'Placement_count'],
#       dtype='object')

# %%
col=['Math_score', 'Reading_score', 'Writing_score', 'Placement_score','Club_joindate', 'Placement_count']
import matplotlib.pyplot as plt
df.boxplot(col)
# Out:
# <Axes: >

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
col1=['Math_score','Reading_score','Writing_score','Placement_count']
df.boxplot(col1)
# Out:
# <Axes: >

# %%
plt.show()

# %%
fig,ax=plt.subplots(figsize=(18,10))

# %%
ax.scatter(df['Placement_score'],df['Placement_count'])

# %%
plt.show()

# %%
df.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score  \
# count   44.000000      39.000000      44.000000        40.000000
# mean    70.431818      91.461538      68.909091        87.825000
# std      5.410574       6.064765       6.279602         5.569549
# min     60.000000      80.000000      60.000000        80.000000
# 25%     66.000000      86.500000      63.000000        83.000000
# 50%     70.000000      92.000000      68.000000        88.000000
# 75%     75.250000      97.500000      73.500000        90.250000
# max     80.000000     100.000000      80.000000       100.000000
#
#        Club_joindate  Placement_count
# count      44.000000        44.000000
# mean     2022.431818         2.818182
# std         1.605191         0.869983
# min      2020.000000         2.000000
# 25%      2021.000000         2.000000
# 50%      2023.000000         3.000000
# 75%      2024.000000         4.000000
# max      2025.000000         4.000000

# %%
import numpy as np
q1=np.percentile(df.Math_score,25)
q2=np.percentile(df.Math_score,50)
q3=np.percentile(df.Math_score,75)
IQR=q3-q1
IQR
# Out:
# np.float64(9.25)

# %%
upper_bod=q3+1.5*IQR
upper_bod
# Out:
# np.float64(89.125)
