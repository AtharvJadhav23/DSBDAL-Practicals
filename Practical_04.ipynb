# %%
import pandas as pd
df=pd.read_csv("Book2.csv")
df
# Out:
#     math_score  reading score   writing score  placement score   \
# 0         75.0            78.0           80.0                75
# 1         66.0            76.0           64.0               100
# 2         66.0            82.0           67.0                75
# 3         63.0            78.0           73.0                83
# 4         60.0            95.0           55.0                95
# ..         ...             ...            ...               ...
# 86        77.0            84.0           66.0                86
# 87        76.0            75.0           80.0                87
# 88        62.0            93.0           63.0                84
# 89        68.0            90.0           69.0                86
# 90        64.0            88.0           78.0                80
#
#     club join year   placement offer count
# 0            2020.0                      2
# 1            2018.0                      3
# 2            2020.0                      2
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of     math_score  reading score   writing score  placement score   \
# 0         75.0            78.0           80.0                75
# 1         66.0            76.0           64.0               100
# 2         66.0            82.0           67.0                75
# 3         63.0            78.0           73.0                83
# 4         60.0            95.0           55.0                95
# ..         ...             ...            ...               ...
# 86        77.0            84.0           66.0                86
# 87        76.0            75.0           80.0                87
# 88        62.0            93.0           63.0                84
# 89        68.0            90.0           69.0                86
# 90        64.0            88.0           78.0                80
#
#     club join year   placement offer count
# 0            2020.0                      2
# 1            2018.0                      3
# ...

# %%
df.notnull
# Out:
# <bound method DataFrame.notnull of     math_score  reading score   writing score  placement score   \
# 0         75.0            78.0           80.0                75
# 1         66.0            76.0           64.0               100
# 2         66.0            82.0           67.0                75
# 3         63.0            78.0           73.0                83
# 4         60.0            95.0           55.0                95
# ..         ...             ...            ...               ...
# 86        77.0            84.0           66.0                86
# 87        76.0            75.0           80.0                87
# 88        62.0            93.0           63.0                84
# 89        68.0            90.0           69.0                86
# 90        64.0            88.0           78.0                80
#
#     club join year   placement offer count
# 0            2020.0                      2
# 1            2018.0                      3
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     math_score  reading score   writing score  placement score   \
# 0         75.0            78.0           80.0                75
# 1         66.0            76.0           64.0               100
# 2         66.0            82.0           67.0                75
# 3         63.0            78.0           73.0                83
# 4         60.0            95.0           55.0                95
# ..         ...             ...            ...               ...
# 86        77.0            84.0           66.0                86
# 87        76.0            75.0           80.0                87
# 88        62.0            93.0           63.0                84
# 89        68.0            90.0           69.0                86
# 90        64.0            88.0           78.0                80
#
#     club join year   placement offer count
# 0            2020.0                      2
# 1            2018.0                      3
# ...

# %%
df.isnull()
# Out:
#     math_score  reading score   writing score  placement score   \
# 0        False           False          False             False
# 1        False           False          False             False
# 2        False           False          False             False
# 3        False           False          False             False
# 4        False           False          False             False
# ..         ...             ...            ...               ...
# 86       False           False          False             False
# 87       False           False          False             False
# 88       False           False          False             False
# 89       False           False          False             False
# 90       False           False          False             False
#
#     club join year   placement offer count
# 0             False                  False
# 1             False                  False
# 2             False                  False
# ...

# %%
df.notnull()
# Out:
#     math_score  reading score   writing score  placement score   \
# 0         True            True           True              True
# 1         True            True           True              True
# 2         True            True           True              True
# 3         True            True           True              True
# 4         True            True           True              True
# ..         ...             ...            ...               ...
# 86        True            True           True              True
# 87        True            True           True              True
# 88        True            True           True              True
# 89        True            True           True              True
# 90        True            True           True              True
#
#     club join year   placement offer count
# 0              True                   True
# 1              True                   True
# 2              True                   True
# ...

# %%
series = pd.isnull(df["math_score"]) 
df[series]
# Out:
#     math_score  reading score   writing score  placement score   \
# 48         NaN            83.0           67.0                80
# 49         NaN            89.0           72.0                93
# 50         NaN            87.0           70.0              1000
# 51         NaN            75.0           70.0                83
# 52         NaN            81.0           61.0                90
# 53         NaN            79.0           76.0                77
#
#     club join year   placement offer count
# 48           2020.0                      2
# 49           2021.0                      3
# 50           2020.0                      3
# 51           2018.0                      2
# 52           2020.0                      3
# 53           2018.0                      2

# %%
ndf=df

# %%
y=df.fillna(0)

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   math_score             91 non-null     float64
#  1   reading score          91 non-null     float64
#  2   writing score          91 non-null     float64
#  3   placement score        91 non-null     int64
#  4   club join year         91 non-null     float64
#  5   placement offer count  91 non-null     int64
# dtypes: float64(4), int64(2)
# memory usage: 4.3 KB

# %%
missing_values = ["Na", "na"] 
df = pd.read_csv("Book2.csv", na_values = 
missing_values) 
df
# Out:
#     math_score  reading score   writing score  placement score   \
# 0         75.0            78.0           80.0                75
# 1         66.0            76.0           64.0               100
# 2         66.0            82.0           67.0                75
# 3         63.0            78.0           73.0                83
# 4         60.0            95.0           55.0                95
# ..         ...             ...            ...               ...
# 86        77.0            84.0           66.0                86
# 87        76.0            75.0           80.0                87
# 88        62.0            93.0           63.0                84
# 89        68.0            90.0           69.0                86
# 90        64.0            88.0           78.0                80
#
#     club join year   placement offer count
# 0            2020.0                      2
# 1            2018.0                      3
# 2            2020.0                      2
# ...
